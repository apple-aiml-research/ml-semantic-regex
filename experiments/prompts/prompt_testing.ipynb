# %% [markdown]
# For licensing see accompanying LICENSE file.
# Copyright (C) 2025 Apple Inc. All Rights Reserved.

# %% [markdown]
# # Prompt Testing
# Test semantic regex generation against hand labeled features.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from test_prompts import run_tests

# %% [markdown]
# ## Test semantic regex descriptions on hand-labeled features

# %%
# Testing varaibles
model = 'gpt-4o-mini'
n_data_examples = 10
context_window_sizes = 32
sampling_method = 'top'
num_runs = 5

# %%
run_tests(
    {
        'models': model,
        'n_data_examples': n_data_examples,
        'context_window_sizes': context_window_sizes,
        'sampling_method': sampling_method,
    },
    num_runs=num_runs
);
# Out:
# 0.00%: ['[:lexeme work:]', '[:lexeme work:]', '@{:context collaboration:}([:lexeme work:])', '[:lexeme work:]', '[:lexeme work:]', '[:lexeme work:]', '[:lexeme work:]', '[:lexeme worked:]', '@{:context collaboration:}([:lexeme work:])', '[:lexeme work:]'] == ['[:symbol worked:]']
# 90.00%: ['[:symbol AW:]', '[:symbol AW:]', '[:symbol AW:]', '[:symbol AW:]', '[:symbol AW:]', '[:symbol AW:]', '[:symbol AW:]', '[:symbol AW:]', '@{:context gaming:}([:symbol AW:])', '[:symbol AW:]'] == ['[:symbol AW:]']
# 30.00%: ['[:field person Hernandez:]', '[:lexeme Hernandez:]', '@{:context law enforcement:}([:symbol Hernandez:])', '[:lexeme Hernandez:]', '[:symbol Hernandez:]', '[:symbol Hernandez:]', '[:symbol Hernandez:]', '[:lexeme Hernandez:]', '@{:context law enforcement:}([:symbol Hernandez:])', '[:lexeme Hernandez:]'] == ['[:symbol Hernandez:]', '@{:context news:}([:symbol Hernandez:])', '@{:context news stories:}([:symbol Hernandez:])']
# ...
